# %%
import numpy as np

# %%
import sage

# %%
conda list
# Out:
# # packages in environment at /home/gregoire/anaconda3/envs/pytorch_fury:
# #
# # Name                    Version                   Build  Channel
# _tflow_select             2.3.0                       mkl
# absl-py                   0.7.0                    py36_0
# anaconda                  custom           py36hbbc8b67_0
# astor                     0.7.1                    py36_0
# attrs                     19.1.0                     py_0
# backcall                  0.1.0                    py36_0
# blas                      1.0                         mkl
# bleach                    3.1.0                    py36_0
# c-ares                    1.15.0               h7b6447c_1
# ca-certificates           2019.3.9             hecc5488_0    conda-forge
# certifi                   2019.3.9                 py36_0    conda-forge
# cffi                      1.12.2           py36h2e261b9_1
# cudatoolkit               9.0                  h13b8566_0
# cudnn                     7.3.1                 cuda9.0_0
# cycler                    0.10.0                   py36_0
# cysignals                 1.10.2                   pypi_0    pypi
# cython                    0.29.10          py36he6710b0_0
# dbus                      1.13.6               h746ee38_0
# decorator                 4.4.0                      py_0
# defusedxml                0.5.0                    py36_1
# doqu                      0.28.2                   pypi_0    pypi
# entrypoints               0.3                      py36_0
# expat                     2.2.6                he6710b0_0
# fontconfig                2.13.0               h9420a91_0
# freetype                  2.9.1                h8a8886c_1
# future                    0.17.1                   py36_0
# gast                      0.2.2                    py36_0
# glib                      2.56.2               hd408876_0
# glpk                      4.65              ha14ba45_1001    conda-forge
# gmp                       6.1.2                h6c8ec71_1
# gmpy2                     2.0.8            py36h10f8cd9_2
# grpcio                    1.16.1           py36hf8bcb03_1
# gst-plugins-base          1.14.0               hbbd80ab_1
# gstreamer                 1.14.0               hb453b48_1
# h5py                      2.9.0            py36h7918eee_0
# hdf5                      1.10.4               hb1b8bf9_0
# icu                       58.2                 h9c2bf20_1
# intel-openmp              2019.1                      144
# ipykernel                 5.1.0            py36h39e3cac_0
# ipython                   7.3.0            py36h39e3cac_0
# ipython_genutils          0.2.0                    py36_0
# ipywidgets                7.4.2                    py36_0
# jedi                      0.13.3                   py36_0
# jinja2                    2.10                     py36_0
# jpeg                      9b                   h024ee3a_2
# jsonschema                3.0.1                    py36_0
# jupyter                   1.0.0                    py36_7
# jupyter_client            5.2.4                    py36_0
# jupyter_console           6.0.0                    py36_0
# jupyter_core              4.4.0                    py36_0
# keras                     2.2.4                         0
# keras-applications        1.0.7                      py_0
# keras-base                2.2.4                    py36_0
# keras-preprocessing       1.0.9                      py_0
# kiwisolver                1.0.1            py36hf484d3e_0
# libedit                   3.1.20181209         hc058e9b_0
# libffi                    3.2.1                hd88cf55_4
# libgcc-ng                 8.2.0                hdf63c60_1
# libgfortran-ng            7.3.0                hdf63c60_0
# libpng                    1.6.36               hbc83047_0
# libprotobuf               3.6.1                hd408876_0
# libsodium                 1.0.16               h1bed415_0
# libstdcxx-ng              8.2.0                hdf63c60_1
# libtiff                   4.0.10               h2733197_2
# libuuid                   1.0.3                h1bed415_2
# libxcb                    1.13                 h1bed415_1
# libxml2                   2.9.9                he19cac6_0
# markdown                  3.0.1                    py36_0
# markupsafe                1.1.1            py36h7b6447c_0
# matplotlib                3.0.3            py36h5429711_0
# mistune                   0.8.4            py36h7b6447c_0
# mkl                       2019.1                      144
# mkl_fft                   1.0.10           py36ha843d7b_0
# mkl_random                1.0.2            py36hd81dba3_0
# modal                     0.3.4                    pypi_0    pypi
# mpc                       1.1.0                h10f8cd9_1
# mpfr                      4.0.1                hdf1c602_3
# nbconvert                 5.4.1                      py_2
# nbformat                  4.4.0                    py36_0
# ncurses                   6.1                  he6710b0_1
# ninja                     1.9.0            py36hfd86e86_0
# notebook                  5.7.6                    py36_0
# numpy                     1.16.2           py36h7e9f1db_0
# numpy-base                1.16.2           py36hde5b4d6_0
# olefile                   0.46                     py36_0
# openssl                   1.1.1b               h14c3975_1    conda-forge
# pandas                    0.24.2           py36he6710b0_0
# pandoc                    2.2.3.2                       0
# pandocfilters             1.4.2                    py36_1
# parso                     0.3.4                    py36_0
# patsy                     0.5.1                    py36_0
# pcre                      8.42                 h439df22_0
# pexpect                   4.6.0                    py36_0
# pickleshare               0.7.5                    py36_0
# pillow                    5.4.1            py36h34e0f95_0
# pip                       19.0.3                   py36_0
# ppl                       1.2               h64e95d0_1002    conda-forge
# prometheus_client         0.6.0                    py36_0
# prompt_toolkit            2.0.9                    py36_0
# protobuf                  3.6.1            py36he6710b0_0
# ptyprocess                0.6.0                    py36_0
# pycparser                 2.19                     py36_0
# pygments                  2.3.1                    py36_0
# pyparsing                 2.3.1                    py36_0
# pyqt                      5.9.2            py36h05f1152_2
# pyrsistent                0.14.11          py36h7b6447c_0
# python                    3.6.8                h0371630_0
# python-dateutil           2.8.0                    py36_0
# pytorch                   1.0.1           cuda90py36h8b0c50b_0
# pytz                      2018.9                   py36_0
# pyyaml                    5.1              py36h7b6447c_0
# pyzmq                     18.0.0           py36he6710b0_0
# qt                        5.9.7                h5867ecd_1
# qtconsole                 4.4.3                    py36_0
# readline                  7.0                  h7b6447c_5
# sage                      0.0.0                    pypi_0    pypi
# scikit-learn              0.20.3           py36hd81dba3_0
# scipy                     1.2.1            py36h7c811a0_0
# seaborn                   0.9.0                    py36_0
# send2trash                1.5.0                    py36_0
# setuptools                40.8.0                   py36_0
# sip                       4.19.8           py36hf484d3e_0
# six                       1.12.0                   py36_0
# skorch                    0.5.0.post0              pypi_0    pypi
# sqlite                    3.26.0               h7b6447c_0
# statsmodels               0.9.0            py36h035aef0_0
# tabulate                  0.8.3                    pypi_0    pypi
# tensorboard               1.12.2           py36he6710b0_0
# tensorflow                1.12.0          mkl_py36h69b6ba0_0
# tensorflow-base           1.12.0          mkl_py36h3c3e929_0
# termcolor                 1.1.0                    py36_1
# terminado                 0.8.1                    py36_1
# testpath                  0.4.2                    py36_0
# tk                        8.6.8                hbc83047_0
# torchvision               0.2.2                      py_3    pytorch
# tornado                   6.0.1            py36h7b6447c_0
# tqdm                      4.31.1                   pypi_0    pypi
# traitlets                 4.3.2                    py36_0
# wcwidth                   0.1.7                    py36_0
# webencodings              0.5.1                    py36_1
# werkzeug                  0.14.1                   py36_0
# wheel                     0.33.1                   py36_0
# widgetsnbextension        3.4.2                    py36_0
# xlrd                      1.2.0                    py36_0
# xz                        5.2.4                h14c3975_4
# yaml                      0.1.7                had09818_2
# zeromq                    4.3.1                he6710b0_3
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.3.7                h0b5b093_0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sage.all_cmdline import *
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-10e8bb635d66> in <module>()
# ----> 1 from sage.all_cmdline import *
#       2
#
# /home/gregoire/anaconda3/envs/pytorch_fury/lib/python3.6/site-packages/sage/all_cmdline.py in <module>()
#      24 sage_mode = 'cmdline'
#      25
# ---> 26 from sage.all import *
#      27 from sage.calculus.predefined import x
#      28
#
# /home/gregoire/anaconda3/envs/pytorch_fury/lib/python3.6/site-packages/sage/all.py in <module>()
#      69 import math
#      70
# ---> 71 from sage.env import SAGE_ROOT, SAGE_SRC, SAGE_DOC_SRC, SAGE_LOCAL, DOT_SAGE, SAGE_ENV
#      72
#      73
#
# /home/gregoire/anaconda3/envs/pytorch_fury/lib/python3.6/site-packages/sage/env.py in <module>()
#     120 _add_variable_or_fallback('SAGE_ROOT',       None)
#     121 _add_variable_or_fallback('SAGE_LOCAL',      None)
# --> 122 _add_variable_or_fallback('SAGE_ETC',        opj('$SAGE_LOCAL', 'etc'))
#     123 _add_variable_or_fallback('SAGE_INC',        opj('$SAGE_LOCAL', 'include'))
#     124 _add_variable_or_fallback('SAGE_SHARE',      opj('$SAGE_LOCAL', 'share'))
#
# /home/gregoire/anaconda3/envs/pytorch_fury/lib/python3.6/site-packages/sage/env.py in _add_variable_or_fallback(key, fallback, force)
#     100                 else:
#     101                     components.append(s)
# --> 102             value = sep.join(components)
#     103         # Now deal with any remaining substitutions. The following is
#     104         # sloppy, as mentioned above: if $VAR and $VAR_NEW are both in
#
# TypeError: sequence item 0: expected str instance, NoneType found

# %%
from sage.all_cmdline import *                      # import sage library
    from sage.libs.ppl import Variable, Linear_Expression, Constraint_System, C_Polyhedron, Generator_System, point, line, ray
